# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#reading dataset
df = pd.read_csv('election_2024.csv')
print(df)

# Exploring the dataset
print("Shape of dataset:", df.shape)
missing = df.isnull().sum()
print("Missing values in each column:\n", missing)
print("Info:\n", df.info())
print("Description:\n", df.describe())
Explanation: Adds basic exploration (shape, missing values, info, stats), showing you’re assessing the data before diving into cleaning. A typical second step.
